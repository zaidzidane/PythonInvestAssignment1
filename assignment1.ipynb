# %%
# !pip install yfinance

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %%
end = date.today()
print(f'Year = {end.year}; month= {end.month}; day={end.day}')

start = date(year=end.year-70, month=end.month, day=end.day)
print(f'Period for indexes: {start} to {end} ')
# Out:
# Year = 2024; month= 4; day=20
# Period for indexes: 1954-04-20 to 2024-04-20

# %%
gdppot = pdr.DataReader("GDPC1", "fred", start='2022-01-01',end='2023-12-31')
gdppot.head()
# Out:
#                 GDPC1
# DATE
# 2022-01-01  21738.871
# 2022-04-01  21708.160
# 2022-07-01  21851.134
# 2022-10-01  21989.981
# 2023-01-01  22112.329

# %%
gdppot['gdppot_us_yoy'] = gdppot.GDPC1/gdppot.GDPC1.shift(4)-1
gdppot.dropna(inplace=True)
gdppot.tail(10)
# Out:
#                 GDPC1  gdppot_us_yoy
# DATE
# 2023-01-01  22112.329       0.017179
# 2023-04-01  22225.350       0.023825
# 2023-07-01  22490.692       0.029269
# 2023-10-01  22679.255       0.031345

# %%
gdppot['gdppot_us_yoy'].mean()
# Out:
# 0.02540443392867625

# %%
gdppot1 = pdr.DataReader("DGS2", "fred", start='2000-01-01')
gdppot1.head()
# Out:
#             DGS2
# DATE
# 2000-01-03  6.38
# 2000-01-04  6.30
# 2000-01-05  6.38
# 2000-01-06  6.35
# 2000-01-07  6.31

# %%
gdppot2 = pdr.DataReader("DGS10", "fred", start='2000-01-01')
gdppot2.head()
# Out:
#             DGS10
# DATE
# 2000-01-03   6.58
# 2000-01-04   6.49
# 2000-01-05   6.62
# 2000-01-06   6.57
# 2000-01-07   6.52

# %%
gdppot3=pd.merge(gdppot2,gdppot1,on='DATE',how='left')

# %%
gdppot3.head()
# Out:
#             DGS10  DGS2
# DATE
# 2000-01-03   6.58  6.38
# 2000-01-04   6.49  6.30
# 2000-01-05   6.62  6.38
# 2000-01-06   6.57  6.35
# 2000-01-07   6.52  6.31

# %%
gdppot3['Treasury_Yield']=gdppot3['DGS10']-gdppot3['DGS2']

# %%
gdppot3['Treasury_Yield'].min()
# Out:
# -1.0800000000000005

# %% [markdown]
# **Question 3. [Index] Which Index is better recently?**

# %%
dax_daily1 = yf.download(tickers = "^GSPC",
                     period = "max",
                     interval = "1d")
dax_daily1.tail()

dax_daily_5Y=dax_daily1.loc['2024-04-09','Open']-dax_daily1.loc['2019-04-09','Close']
dax_daily_5Y_val=dax_daily_5Y/dax_daily1.loc['2019-04-09','Open']
dax_daily_5Y_val
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.8102424913510731

# %%
dax_daily2 = yf.download(tickers = "^MXX",
                     period = "max",
                     interval = "3mo")
dax_daily2.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2023-05-01  55059.261719  55626.511719  52575.140625  54819.050781
# 2023-08-01  54791.480469  54901.898438  47765.058594  49061.878906
# 2023-11-01  49051.921875  58338.320312  48976.859375  57372.761719
# 2024-02-01  57367.281250  59020.550781  54713.480469  55862.851562
# 2024-04-19  55811.191406  56036.718750  55579.691406  55862.851562
#
#                Adj Close       Volume
# Date
# 2023-05-01  54819.050781  14028050800
# 2023-08-01  49061.878906  16892340700
# 2023-11-01  57372.761719  11883857200
# 2024-02-01  55862.851562  10735081200
# 2024-04-19  55862.851562    138617598

# %%
dax_daily1 = yf.download(tickers = "^MXX",
                     period = "max",
                     interval = "1d")
dax_daily1.tail()

dax_daily_5Y=dax_daily1.loc['2024-04-09','Open']-dax_daily1.loc['2019-04-09','Close']
dax_daily_5Y_val=dax_daily_5Y/dax_daily1.loc['2019-04-09','Open']
dax_daily_5Y_val
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.2835643135183449

# %%
dax_daily1 = yf.download(tickers = "MSFT",
                     period = "max",
                     interval = "1d")


dax_daily1 = dax_daily1[(dax_daily1.index >= '2023-01-01') & (dax_daily1.index < '2024-01-01')]

val=(dax_daily1['Adj Close'].max()-dax_daily1['Adj Close'].min())/dax_daily1['Adj Close'].max()
print(val)
# dax_daily1.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.4242066116078822

# %%
# get actions, incl. dividends - as a dataFrame
epi = yf.Ticker('2222.SR')
epi.dividends(start="2023-01-01", end='2024-01-01')
# epi = epi[(epi.index >= '2023-01-01') & (epi.index < '2024-01-01')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-dc1183df0607> in <cell line: 3>()
#       1 # get actions, incl. dividends - as a dataFrame
#       2 epi = yf.Ticker('2222.SR')
# ----> 3 epi.dividends(start="2023-01-01", end='2024-01-01')
#       4 # epi = epi[(epi.index >= '2023-01-01') & (epi.index < '2024-01-01')]
#
# TypeError: 'Series' object is not callable

# %%
epi.get_actions()
# Out:
#                            Dividends  Stock Splits
# Date
# 2020-03-19 00:00:00+03:00   0.060992           0.0
# 2020-05-31 00:00:00+03:00   0.290744           0.0
# 2020-06-04 00:00:00+03:00   0.000000           1.1
# 2020-06-08 00:00:00+03:00   0.000000           1.1
# 2020-08-12 00:00:00+03:00   0.290744           0.0
# 2020-11-10 00:00:00+03:00   0.290744           0.0
# 2021-03-23 00:00:00+03:00   0.290744           0.0
# 2021-05-17 00:00:00+03:00   0.290744           0.0
# 2021-08-16 00:00:00+03:00   0.290744           0.0
# 2021-11-07 00:00:00+03:00   0.290744           0.0
# 2022-05-15 00:00:00+03:00   0.000000           1.1
# 2022-05-24 00:00:00+03:00   0.290727           0.0
# 2022-08-22 00:00:00+03:00   0.290727           0.0
# 2022-11-09 00:00:00+03:00   0.290727           0.0
# 2023-03-15 00:00:00+03:00   0.302364           0.0
# 2023-05-09 00:00:00+03:00   0.000000           1.1
# 2023-05-17 00:00:00+03:00   0.302400           0.0
# ...

# %%
epi.dividends.sum()
# Out:
# 4.046145

# %%
import yfinance as yf

# Creating a Ticker object for the stock
epi = yf.Ticker('2222.SR')

# Retrieving dividend data within the specified date range
df=epi.dividends
df_1 = df[(df.index >= '2023-01-01') & (df.index < '2024-01-01')]
print(df_1)
df_1 =df_1.sum()
# Displaying the dividend history
# print(dividend_history)
dax_daily1 = yf.download(tickers = "2222.SR",
                     period = "max",
                     interval = "1d")


dax_daily1 = dax_daily1[(dax_daily1.index >= '2023-12-01') & (dax_daily1.index < '2024-01-01')]
last_adj_close = dax_daily1['Adj Close'].iloc[-1]
print(df_1,last_adj_close)
a=df_1/last_adj_close
print(a)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2023-03-15 00:00:00+03:00    0.302364
# 2023-05-17 00:00:00+03:00    0.302400
# 2023-09-11 00:00:00+03:00    0.153000
# 2023-11-15 00:00:00+03:00    0.153000
# Name: Dividends, dtype: float64
# 0.9107640000000001 32.82804870605469
# 0.027743470474138235
